# %%
import agent
from environment import Agent, Environment
from planner import RoutePlanner
from simulator import Simulator

# %%
    """Run the agent for a finite number of trials."""

    # Set up environment and agent
    e = Environment()  # create environment (also adds some dummy traffic)
    a = e.create_agent(agent.LearningAgent)  # create agent
    e.set_primary_agent(a, enforce_deadline=True)  # specify agent to track
    # NOTE: You can set enforce_deadline=False while debugging to allow longer trials

    # Now simulate it
    sim = Simulator(e, update_delay=0, display=False)  # create simulator (uses pygame when display=True, if available)
    # NOTE: To speed up simulation, reduce update_delay and/or set display=False

    sim.run(n_trials=100)  # run for a specified number of trials
    # NOTE: To quit midway, press Esc or close pygame window, or hit Ctrl+C on the command-line
    # for i in a.qt.items(): print(str(i).replace('(','').replace(')','').replace('\'','').replace(' ',''))
# Out:
# Simulator.run(): Trial 0
# Environment.reset(): Trial set up with start = (4, 6), destination = (1, 1), deadline = 40
# RoutePlanner.route_to(): destination = (1, 1)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 1
# Environment.reset(): Trial set up with start = (3, 5), destination = (3, 1), deadline = 20
# RoutePlanner.route_to(): destination = (3, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 2
# Environment.reset(): Trial set up with start = (4, 2), destination = (6, 6), deadline = 30
# RoutePlanner.route_to(): destination = (6, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 3
# Environment.reset(): Trial set up with start = (4, 3), destination = (6, 5), deadline = 20
# RoutePlanner.route_to(): destination = (6, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 4
# Environment.reset(): Trial set up with start = (2, 6), destination = (8, 2), deadline = 50
# RoutePlanner.route_to(): destination = (8, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 5
# Environment.reset(): Trial set up with start = (7, 6), destination = (1, 3), deadline = 45
# RoutePlanner.route_to(): destination = (1, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 6
# Environment.reset(): Trial set up with start = (7, 1), destination = (1, 3), deadline = 40
# RoutePlanner.route_to(): destination = (1, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 7
# Environment.reset(): Trial set up with start = (4, 4), destination = (5, 1), deadline = 20
# RoutePlanner.route_to(): destination = (5, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 8
# Environment.reset(): Trial set up with start = (6, 5), destination = (2, 5), deadline = 20
# RoutePlanner.route_to(): destination = (2, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 9
# Environment.reset(): Trial set up with start = (4, 2), destination = (7, 3), deadline = 20
# RoutePlanner.route_to(): destination = (7, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 10
# Environment.reset(): Trial set up with start = (5, 6), destination = (1, 4), deadline = 30
# RoutePlanner.route_to(): destination = (1, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 11
# Environment.reset(): Trial set up with start = (7, 6), destination = (3, 2), deadline = 40
# RoutePlanner.route_to(): destination = (3, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 12
# Environment.reset(): Trial set up with start = (8, 1), destination = (4, 3), deadline = 30
# RoutePlanner.route_to(): destination = (4, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 13
# Environment.reset(): Trial set up with start = (8, 5), destination = (2, 3), deadline = 40
# RoutePlanner.route_to(): destination = (2, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 14
# Environment.reset(): Trial set up with start = (7, 5), destination = (3, 5), deadline = 20
# RoutePlanner.route_to(): destination = (3, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 15
# Environment.reset(): Trial set up with start = (4, 2), destination = (1, 4), deadline = 25
# RoutePlanner.route_to(): destination = (1, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 16
# Environment.reset(): Trial set up with start = (2, 6), destination = (7, 5), deadline = 30
# RoutePlanner.route_to(): destination = (7, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 17
# Environment.reset(): Trial set up with start = (5, 2), destination = (1, 6), deadline = 40
# RoutePlanner.route_to(): destination = (1, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 18
# Environment.reset(): Trial set up with start = (4, 4), destination = (6, 2), deadline = 20
# RoutePlanner.route_to(): destination = (6, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 19
# Environment.reset(): Trial set up with start = (5, 5), destination = (2, 6), deadline = 20
# RoutePlanner.route_to(): destination = (2, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 20
# Environment.reset(): Trial set up with start = (4, 5), destination = (5, 1), deadline = 25
# RoutePlanner.route_to(): destination = (5, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 21
# Environment.reset(): Trial set up with start = (6, 3), destination = (8, 5), deadline = 20
# RoutePlanner.route_to(): destination = (8, 5)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 22
# Environment.reset(): Trial set up with start = (3, 6), destination = (5, 4), deadline = 20
# RoutePlanner.route_to(): destination = (5, 4)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 23
# Environment.reset(): Trial set up with start = (1, 1), destination = (5, 2), deadline = 25
# RoutePlanner.route_to(): destination = (5, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 24
# Environment.reset(): Trial set up with start = (5, 6), destination = (6, 3), deadline = 20
# RoutePlanner.route_to(): destination = (6, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 25
# Environment.reset(): Trial set up with start = (2, 5), destination = (8, 2), deadline = 45
# RoutePlanner.route_to(): destination = (8, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 26
# Environment.reset(): Trial set up with start = (2, 6), destination = (6, 2), deadline = 40
# RoutePlanner.route_to(): destination = (6, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 27
# Environment.reset(): Trial set up with start = (5, 2), destination = (1, 4), deadline = 30
# RoutePlanner.route_to(): destination = (1, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 28
# Environment.reset(): Trial set up with start = (2, 5), destination = (1, 1), deadline = 25
# RoutePlanner.route_to(): destination = (1, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 29
# Environment.reset(): Trial set up with start = (5, 6), destination = (1, 1), deadline = 45
# RoutePlanner.route_to(): destination = (1, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 30
# Environment.reset(): Trial set up with start = (8, 1), destination = (7, 5), deadline = 25
# RoutePlanner.route_to(): destination = (7, 5)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 31
# Environment.reset(): Trial set up with start = (3, 4), destination = (2, 1), deadline = 20
# RoutePlanner.route_to(): destination = (2, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 32
# Environment.reset(): Trial set up with start = (5, 6), destination = (6, 1), deadline = 30
# RoutePlanner.route_to(): destination = (6, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 33
# Environment.reset(): Trial set up with start = (4, 5), destination = (6, 2), deadline = 25
# RoutePlanner.route_to(): destination = (6, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 34
# Environment.reset(): Trial set up with start = (2, 4), destination = (8, 2), deadline = 40
# RoutePlanner.route_to(): destination = (8, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 35
# Environment.reset(): Trial set up with start = (8, 4), destination = (4, 2), deadline = 30
# RoutePlanner.route_to(): destination = (4, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 36
# Environment.reset(): Trial set up with start = (4, 1), destination = (8, 6), deadline = 45
# RoutePlanner.route_to(): destination = (8, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 37
# Environment.reset(): Trial set up with start = (8, 2), destination = (1, 4), deadline = 45
# RoutePlanner.route_to(): destination = (1, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 38
# Environment.reset(): Trial set up with start = (8, 1), destination = (5, 3), deadline = 25
# RoutePlanner.route_to(): destination = (5, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 39
# Environment.reset(): Trial set up with start = (1, 1), destination = (8, 3), deadline = 45
# RoutePlanner.route_to(): destination = (8, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 40
# Environment.reset(): Trial set up with start = (2, 1), destination = (5, 6), deadline = 40
# RoutePlanner.route_to(): destination = (5, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 41
# Environment.reset(): Trial set up with start = (4, 2), destination = (8, 5), deadline = 35
# RoutePlanner.route_to(): destination = (8, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 42
# Environment.reset(): Trial set up with start = (1, 2), destination = (5, 3), deadline = 25
# RoutePlanner.route_to(): destination = (5, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 43
# Environment.reset(): Trial set up with start = (6, 2), destination = (5, 6), deadline = 25
# RoutePlanner.route_to(): destination = (5, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 44
# Environment.reset(): Trial set up with start = (3, 6), destination = (6, 3), deadline = 30
# RoutePlanner.route_to(): destination = (6, 3)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 45
# Environment.reset(): Trial set up with start = (2, 5), destination = (7, 6), deadline = 30
# RoutePlanner.route_to(): destination = (7, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 46
# Environment.reset(): Trial set up with start = (2, 2), destination = (8, 4), deadline = 40
# RoutePlanner.route_to(): destination = (8, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 47
# Environment.reset(): Trial set up with start = (6, 5), destination = (4, 1), deadline = 30
# RoutePlanner.route_to(): destination = (4, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 48
# Environment.reset(): Trial set up with start = (8, 1), destination = (4, 1), deadline = 20
# RoutePlanner.route_to(): destination = (4, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 49
# Environment.reset(): Trial set up with start = (7, 3), destination = (1, 4), deadline = 35
# RoutePlanner.route_to(): destination = (1, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 50
# Environment.reset(): Trial set up with start = (6, 1), destination = (4, 4), deadline = 25
# RoutePlanner.route_to(): destination = (4, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 51
# Environment.reset(): Trial set up with start = (8, 6), destination = (6, 1), deadline = 35
# RoutePlanner.route_to(): destination = (6, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 52
# Environment.reset(): Trial set up with start = (7, 4), destination = (5, 1), deadline = 25
# RoutePlanner.route_to(): destination = (5, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 53
# Environment.reset(): Trial set up with start = (3, 1), destination = (7, 4), deadline = 35
# RoutePlanner.route_to(): destination = (7, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 54
# Environment.reset(): Trial set up with start = (1, 3), destination = (4, 4), deadline = 20
# RoutePlanner.route_to(): destination = (4, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 55
# Environment.reset(): Trial set up with start = (8, 4), destination = (5, 6), deadline = 25
# RoutePlanner.route_to(): destination = (5, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 56
# Environment.reset(): Trial set up with start = (3, 6), destination = (8, 6), deadline = 25
# RoutePlanner.route_to(): destination = (8, 6)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 57
# Environment.reset(): Trial set up with start = (5, 2), destination = (1, 6), deadline = 40
# RoutePlanner.route_to(): destination = (1, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 58
# Environment.reset(): Trial set up with start = (6, 4), destination = (2, 2), deadline = 30
# RoutePlanner.route_to(): destination = (2, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 59
# Environment.reset(): Trial set up with start = (8, 4), destination = (3, 2), deadline = 35
# RoutePlanner.route_to(): destination = (3, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 60
# Environment.reset(): Trial set up with start = (7, 1), destination = (4, 5), deadline = 35
# RoutePlanner.route_to(): destination = (4, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 61
# Environment.reset(): Trial set up with start = (5, 1), destination = (1, 3), deadline = 30
# RoutePlanner.route_to(): destination = (1, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 62
# Environment.reset(): Trial set up with start = (7, 1), destination = (8, 6), deadline = 30
# RoutePlanner.route_to(): destination = (8, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 63
# Environment.reset(): Trial set up with start = (2, 2), destination = (4, 5), deadline = 25
# RoutePlanner.route_to(): destination = (4, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 64
# Environment.reset(): Trial set up with start = (2, 2), destination = (1, 6), deadline = 25
# RoutePlanner.route_to(): destination = (1, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 65
# Environment.reset(): Trial set up with start = (1, 2), destination = (7, 5), deadline = 45
# RoutePlanner.route_to(): destination = (7, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 66
# Environment.reset(): Trial set up with start = (8, 4), destination = (2, 4), deadline = 30
# RoutePlanner.route_to(): destination = (2, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 67
# Environment.reset(): Trial set up with start = (4, 2), destination = (2, 5), deadline = 25
# RoutePlanner.route_to(): destination = (2, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 68
# Environment.reset(): Trial set up with start = (4, 2), destination = (6, 6), deadline = 30
# RoutePlanner.route_to(): destination = (6, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 69
# Environment.reset(): Trial set up with start = (7, 3), destination = (3, 6), deadline = 35
# RoutePlanner.route_to(): destination = (3, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 70
# Environment.reset(): Trial set up with start = (1, 3), destination = (8, 5), deadline = 45
# RoutePlanner.route_to(): destination = (8, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 71
# Environment.reset(): Trial set up with start = (4, 3), destination = (1, 4), deadline = 20
# RoutePlanner.route_to(): destination = (1, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 72
# Environment.reset(): Trial set up with start = (8, 1), destination = (7, 4), deadline = 20
# RoutePlanner.route_to(): destination = (7, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 73
# Environment.reset(): Trial set up with start = (1, 1), destination = (6, 5), deadline = 45
# RoutePlanner.route_to(): destination = (6, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 74
# Environment.reset(): Trial set up with start = (8, 1), destination = (7, 5), deadline = 25
# RoutePlanner.route_to(): destination = (7, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 75
# Environment.reset(): Trial set up with start = (7, 4), destination = (2, 2), deadline = 35
# RoutePlanner.route_to(): destination = (2, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 76
# Environment.reset(): Trial set up with start = (6, 2), destination = (2, 5), deadline = 35
# RoutePlanner.route_to(): destination = (2, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 77
# Environment.reset(): Trial set up with start = (1, 3), destination = (7, 5), deadline = 40
# RoutePlanner.route_to(): destination = (7, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 78
# Environment.reset(): Trial set up with start = (1, 5), destination = (4, 1), deadline = 35
# RoutePlanner.route_to(): destination = (4, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 79
# Environment.reset(): Trial set up with start = (8, 6), destination = (2, 4), deadline = 40
# RoutePlanner.route_to(): destination = (2, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 80
# Environment.reset(): Trial set up with start = (7, 4), destination = (2, 3), deadline = 30
# RoutePlanner.route_to(): destination = (2, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 81
# Environment.reset(): Trial set up with start = (7, 2), destination = (8, 6), deadline = 25
# RoutePlanner.route_to(): destination = (8, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 82
# Environment.reset(): Trial set up with start = (3, 4), destination = (6, 2), deadline = 25
# RoutePlanner.route_to(): destination = (6, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 83
# Environment.reset(): Trial set up with start = (8, 5), destination = (5, 2), deadline = 30
# RoutePlanner.route_to(): destination = (5, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 84
# Environment.reset(): Trial set up with start = (2, 3), destination = (6, 4), deadline = 25
# RoutePlanner.route_to(): destination = (6, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 85
# Environment.reset(): Trial set up with start = (4, 1), destination = (6, 3), deadline = 20
# RoutePlanner.route_to(): destination = (6, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 86
# Environment.reset(): Trial set up with start = (2, 2), destination = (7, 4), deadline = 35
# RoutePlanner.route_to(): destination = (7, 4)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 87
# Environment.reset(): Trial set up with start = (8, 2), destination = (5, 1), deadline = 20
# RoutePlanner.route_to(): destination = (5, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 88
# Environment.reset(): Trial set up with start = (8, 1), destination = (2, 1), deadline = 30
# RoutePlanner.route_to(): destination = (2, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 89
# Environment.reset(): Trial set up with start = (7, 1), destination = (2, 1), deadline = 25
# RoutePlanner.route_to(): destination = (2, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 90
# Environment.reset(): Trial set up with start = (8, 2), destination = (4, 1), deadline = 25
# RoutePlanner.route_to(): destination = (4, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 91
# Environment.reset(): Trial set up with start = (4, 4), destination = (1, 6), deadline = 25
# RoutePlanner.route_to(): destination = (1, 6)
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Simulator.run(): Trial 92
# Environment.reset(): Trial set up with start = (8, 3), destination = (3, 3), deadline = 25
# RoutePlanner.route_to(): destination = (3, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 93
# Environment.reset(): Trial set up with start = (2, 2), destination = (3, 5), deadline = 20
# RoutePlanner.route_to(): destination = (3, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 94
# Environment.reset(): Trial set up with start = (8, 2), destination = (1, 2), deadline = 35
# RoutePlanner.route_to(): destination = (1, 2)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 95
# Environment.reset(): Trial set up with start = (6, 2), destination = (5, 5), deadline = 20
# RoutePlanner.route_to(): destination = (5, 5)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 96
# Environment.reset(): Trial set up with start = (8, 3), destination = (6, 6), deadline = 25
# RoutePlanner.route_to(): destination = (6, 6)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 97
# Environment.reset(): Trial set up with start = (6, 6), destination = (8, 1), deadline = 35
# RoutePlanner.route_to(): destination = (8, 1)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 98
# Environment.reset(): Trial set up with start = (1, 2), destination = (4, 3), deadline = 20
# RoutePlanner.route_to(): destination = (4, 3)
# Environment.act(): Primary agent has reached destination!
# Simulator.run(): Trial 99
# Environment.reset(): Trial set up with start = (7, 4), destination = (3, 2), deadline = 30
# RoutePlanner.route_to(): destination = (3, 2)
# Environment.act(): Primary agent has reached destination!

# %%
import numpy as np
for i in range(0,100,10):
    print ('reward ' + str(np.mean(a.reward_tracker[i:i+10])))
    print ('penalty ' + str(np.mean(a.penalty_tracker[i:i+10])))
# Out:
# reward 20.8
# penalty 2.5
# reward 21.5
# penalty 0.4
# reward 22.1
# penalty 1.7
# reward 20.1
# penalty 2.5
# reward 21.6
# penalty 1.7
# reward 25.75
# penalty 3.5
# reward 29.05
# penalty 4.1
# reward 24.6
# penalty 3.1
# reward 23.95
# penalty 2.2
# reward 21.95
# penalty 1.7

# %%
import numpy as np
print (np.mean(a.penalty_tracker[0:10]))
print (np.mean(a.penalty_tracker[10:20]))
print (np.mean(a.penalty_tracker[20:30]))
print (np.mean(a.penalty_tracker[30:40]))
print (np.mean(a.penalty_tracker[40:50]))
print (np.mean(a.penalty_tracker[50:60]))
print (np.mean(a.penalty_tracker[60:70]))
print (np.mean(a.penalty_tracker[70:80]))
print (np.mean(a.penalty_tracker[90:100]))
# Out:
# 2.5
# 0.4
# 1.7
# 2.5
# 1.7
# 3.5
# 4.1
# 3.1
# 1.7

# %%
# turn qt into df
for i in a.qt.items():
a.qt
# Out:
# {(('forward', 'red', None, 'forward'), None): 3.3480934210936932,
#  (('left', 'red', 'left', None), 'forward'): 0.1250118608076429,
#  (('left', 'red', 'left', None), None): 4.264597805442614,
#  (('forward', 'green', 'left', 'right'), None): 0,
#  (('forward', 'red', 'forward', 'left'), 'right'): 0,
#  (('left', 'green', None, 'left'), None): 0.0,
#  (('left', 'green', 'right', 'forward'), 'forward'): 0,
#  (('forward', 'red', 'right', 'forward'), 'left'): 0,
#  (('forward', 'green', 'forward', 'right'), 'left'): 0,
#  (('right', 'green', None, 'forward'), 'left'): 0,
#  (('left', 'red', 'left', None), 'right'): 0.7672508103102624,
#  (('left', 'red', 'forward', 'left'), None): 0,
#  (('forward', 'red', 'forward', None), None): 0,
#  (('right', 'red', 'left', 'left'), 'forward'): 0,
#  (('forward', 'red', 'right', 'right'), 'forward'): 0,
#  (('right', 'red', 'right', 'right'), 'forward'): 0,
#  (('left', 'green', None, 'forward'), 'left'): 6.016783085077673,
#  (('right', 'green', 'left', 'forward'), 'left'): 0,
#  (('right', 'red', 'forward', 'right'), 'forward'): 0,
#  (('right', 'green', 'right', 'left'), 'left'): 0,
#  (('right', 'red', 'forward', 'right'), 'left'): 0,
#  (('forward', 'green', 'left', 'left'), 'right'): 0,
#  (('forward', 'red', None, 'forward'), 'forward'): 0,
#  (('forward', 'green', 'forward', None), 'left'): 0,
#  (('left', 'green', 'right', 'left'), 'forward'): 0,
#  (('forward', 'green', 'forward', None), None): 0,
#  (('left', 'red', None, 'right'), None): 2.6143390567157314,
#  (('left', 'red', 'left', 'right'), 'left'): 0,
#  (('right', 'green', 'left', None), 'forward'): 6.212471671554667,
#  (('forward', 'green', 'left', 'forward'), 'left'): 0,
#  (('forward', 'green', 'right', 'forward'), 'forward'): 0,
#  (('left', 'red', None, 'right'), 'left'): 0.4933764861264903,
#  (('right', 'red', 'left', 'right'), 'right'): 0,
#  (('right', 'green', 'forward', 'left'), 'left'): 0,
#  (('left', 'red', None, 'forward'), 'left'): 0,
#  (('left', 'red', 'forward', 'left'), 'left'): 0,
#  (('right', 'red', 'left', 'left'), 'left'): 0,
#  (('forward', 'red', None, 'right'), 'right'): 3.615771083740027,
#  (('right', 'green', 'right', 'left'), 'right'): 0,
#  (('forward', 'red', 'right', 'right'), None): 0,
#  (('left', 'green', 'left', None), 'right'): 0,
#  (('forward', 'red', None, 'right'), None): 0,
#  (('forward', 'red', 'left', 'right'), 'left'): 0,
#  (('left', 'green', 'forward', 'left'), 'forward'): 0,
#  (('forward', 'red', 'forward', None), 'forward'): 0.18635631703329808,
#  (('forward', 'green', None, 'left'), 'left'): 2.840002125708878,
#  (('right', 'green', 'right', 'right'), None): 0,
#  (('right', 'green', 'right', 'forward'), 'forward'): 0,
#  (('right', 'red', 'left', 'forward'), 'forward'): 0,
#  (('right', 'green', 'right', None), None): 0,
#  (('right', 'red', 'right', 'left'), 'left'): 0,
#  (('forward', 'red', 'left', None), None): 3.970259976971708,
#  (('left', 'red', 'forward', 'right'), 'forward'): 0,
#  (('right', 'red', None, 'forward'), 'forward'): 0,
#  (('right', 'red', 'left', None), 'right'): 7.537327051592764,
#  (('left', 'red', 'right', 'left'), 'forward'): 0,
#  (('forward', 'red', 'right', 'forward'), None): 0}

# %%
to_str = lambda x: str(x).replace('(','').replace(')','').replace('\'','').replace(' ','')

# %%
arr = []
for i in map(to_str, a.qt.items()):
    arr.append(i.split(','))

# %%
arr
# Out:
# [['forward', 'red', 'None', 'forward', 'None', '3.678748210927025'],
#  ['left', 'red', 'left', 'None', 'forward', '0'],
#  ['left', 'red', 'left', 'None', 'None', '4.025578411370011'],
#  ['forward', 'green', 'left', 'right', 'None', '0'],
#  ['forward', 'red', 'forward', 'left', 'right', '0'],
#  ['left', 'green', 'None', 'left', 'None', '0.49005492241889165'],
#  ['left', 'green', 'right', 'forward', 'forward', '0'],
#  ['forward', 'red', 'right', 'forward', 'left', '0'],
#  ['forward', 'green', 'forward', 'right', 'left', '0'],
#  ['right', 'green', 'None', 'forward', 'left', '1.0355756747201827'],
#  ['left', 'red', 'left', 'None', 'right', '0'],
#  ['left', 'red', 'forward', 'left', 'None', '0'],
#  ['forward', 'red', 'forward', 'None', 'None', '7.037651954668828'],
#  ['right', 'red', 'left', 'left', 'forward', '0'],
#  ['forward', 'red', 'right', 'None', 'forward', '0'],
#  ['forward', 'green', 'None', 'left', 'forward', '0'],
#  ['right', 'green', 'forward', 'right', 'None', '0'],
#  ['left', 'green', 'right', 'forward', 'right', '0'],
#  ['forward', 'green', 'right', 'left', 'None', '0'],
#  ['left', 'green', 'None', 'left', 'forward', '0'],
#  ['left', 'green', 'forward', 'None', 'None', '0'],
#  ['left', 'green', 'None', 'left', 'left', '0'],
#  ['left', 'red', 'right', 'left', 'None', '0'],
#  ['right', 'red', 'left', 'left', 'right', '0'],
#  ['forward', 'green', 'right', 'forward', 'right', '0'],
#  ['right', 'red', 'right', 'left', 'forward', '0'],
#  ['forward', 'red', 'left', 'None', 'right', '6.229636886231188'],
#  ['right', 'red', 'forward', 'left', 'None', '0'],
#  ['left', 'green', 'left', 'left', 'right', '0'],
#  ['left', 'red', 'left', 'left', 'forward', '0'],
#  ['forward', 'red', 'left', 'left', 'None', '0'],
#  ['right', 'red', 'right', 'left', 'right', '0'],
#  ['left', 'green', 'forward', 'right', 'right', '0'],
#  ['right', 'green', 'left', 'None', 'None', '0'],
#  ['left', 'green', 'forward', 'left', 'None', '0'],
#  ['forward', 'green', 'forward', 'left', 'right', '0'],
#  ['left', 'green', 'None', 'None', 'None', '7.93279986306535'],
#  ['right', 'green', 'forward', 'forward', 'None', '0'],
#  ['forward', 'green', 'forward', 'None', 'right', '0'],
#  ['right', 'red', 'forward', 'None', 'right', '1.755151926308809'],
#  ['right', 'green', 'right', 'right', 'left', '0'],
#  ['left', 'red', 'forward', 'right', 'right', '0'],
#  ['forward', 'green', 'right', 'None', 'forward', '3.2664240614906204'],
#  ['left', 'red', 'None', 'None', 'forward', '5.062013639168497'],
#  ['left', 'green', 'None', 'right', 'left', '0'],
#  ['left', 'green', 'left', 'None', 'forward', '0'],
#  ['right', 'green', 'forward', 'forward', 'right', '0'],
#  ['left', 'red', 'right', 'right', 'None', '0'],
#  ['forward', 'red', 'left', 'forward', 'None', '0.452303059645349'],
#  ['left', 'green', 'forward', 'forward', 'right', '0'],
#  ['forward', 'red', 'forward', 'left', 'forward', '0'],
#  ['right', 'green', 'None', 'right', 'left', '3.362465467035018'],
#  ['right', 'green', 'right', 'None', 'forward', '0'],
#  ['right', 'green', 'forward', 'forward', 'forward', '0'],
#  ['left', 'red', 'right', 'None', 'forward', '0.49017858856671304'],
#  ['left', 'red', 'left', 'left', 'right', '0'],
#  ['left', 'red', 'None', 'forward', 'right', '0'],
#  ['forward', 'green', 'left', 'forward', 'None', '0.0'],
#  ['right', 'red', 'left', 'None', 'None', '0.2030418710772254'],
#  ['forward', 'green', 'left', 'None', 'left', '1.3076805721942877'],
#  ['right', 'green', 'left', 'None', 'left', '0'],
#  ['left', 'green', 'None', 'forward', 'None', '0'],
#  ['right', 'green', 'forward', 'None', 'forward', '2.9420259253301815'],
#  ['right', 'green', 'None', 'left', 'None', '0.9497510539488747'],
#  ['forward', 'red', 'forward', 'forward', 'forward', '0'],
#  ['forward', 'green', 'None', 'None', 'left', '7.279828981144089'],
#  ['forward', 'green', 'left', 'None', 'right', '0.46647022512227254'],
#  ['forward', 'red', 'right', 'None', 'right', '0'],
#  ['forward', 'green', 'right', 'forward', 'None', '0'],
#  ['left', 'red', 'right', 'forward', 'None', '0'],
#  ['forward', 'red', 'left', 'right', 'forward', '0'],
#  ['right', 'green', 'left', 'left', 'right', '0'],
#  ['left', 'green', 'forward', 'left', 'left', '0.3900549224188916'],
#  ['forward', 'green', 'forward', 'left', 'None', '0'],
#  ['right', 'red', 'right', 'forward', 'left', '0'],
#  ['forward', 'red', 'None', 'None', 'None', '5.628498644008896'],
#  ['forward', 'red', 'left', 'None', 'left', '0.13550268537398683'],
#  ['right', 'red', 'None', 'right', 'right', '3.8532480799826856'],
#  ['left', 'red', 'left', 'forward', 'None', '0'],
#  ['left', 'green', 'None', 'right', 'None', '0'],
#  ['right', 'red', 'right', 'forward', 'forward', '0'],
#  ['left', 'green', 'forward', 'forward', 'left', '0'],
#  ['right', 'red', 'right', 'left', 'None', '0'],
#  ['left', 'green', 'right', 'None', 'forward', '0'],
#  ['right', 'red', 'forward', 'None', 'forward', '0.5455503793919864'],
#  ['forward', 'green', 'left', 'forward', 'right', '0'],
#  ['forward', 'green', 'forward', 'right', 'forward', '0'],
#  ['forward', 'red', 'left', 'right', 'right', '0'],
#  ['forward', 'red', 'right', 'right', 'left', '0'],
#  ['left', 'green', 'None', 'forward', 'right', '0.7197772696890368'],
#  ['forward', 'green', 'right', 'left', 'left', '0'],
#  ['right', 'green', 'forward', 'left', 'forward', '0'],
#  ['right', 'red', 'None', 'right', 'forward', '0.7211789419060909'],
#  ['forward', 'green', 'None', 'right', 'forward', '0'],
#  ['right', 'green', 'right', 'left', 'forward', '0'],
#  ['forward', 'green', 'forward', 'right', 'right', '0'],
#  ['left', 'green', 'left', 'forward', 'right', '0'],
#  ['left', 'green', 'None', 'right', 'right', '0'],
#  ['forward', 'red', 'right', 'None', 'left', '3.109823135426045'],
#  ['left', 'green', 'left', 'right', 'right', '0'],
#  ['forward', 'green', 'right', 'right', 'left', '0'],
#  ['forward', 'red', 'right', 'left', 'right', '0'],
#  ['forward', 'red', 'None', 'forward', 'right', '0'],
#  ['right', 'green', 'None', 'right', 'None', '0'],
#  ['left', 'green', 'None', 'left', 'right', '6.5644237158437635'],
#  ['right', 'red', 'forward', 'forward', 'right', '0'],
#  ['forward', 'green', 'left', 'None', 'forward', '9.109371390345478'],
#  ['left', 'green', 'left', 'left', 'None', '0'],
#  ['forward', 'red', 'forward', 'None', 'right', '1.5631016380524214'],
#  ['right', 'green', 'right', 'forward', 'right', '0'],
#  ['forward', 'green', 'right', 'None', 'None', '0'],
#  ['left', 'green', 'forward', 'forward', 'None', '0'],
#  ['right', 'green', 'None', 'left', 'left', '0'],
#  ['right', 'red', 'forward', 'None', 'left', '0.6127797129510929'],
#  ['right', 'green', 'left', 'None', 'right', '0'],
#  ['right', 'red', 'forward', 'forward', 'left', '0'],
#  ['left', 'green', 'right', 'forward', 'None', '0'],
#  ['forward', 'green', 'right', 'None', 'left', '0'],
#  ['right', 'red', 'forward', 'forward', 'forward', '-0.07464876745080987'],
#  ['right', 'green', 'right', 'forward', 'left', '0'],
#  ['forward', 'green', 'None', 'right', 'left', '0'],
#  ['right', 'red', 'left', 'left', 'None', '0'],
#  ['right', 'green', 'right', 'None', 'right', '1.003995513840499'],
#  ['right', 'red', 'forward', 'left', 'left', '0'],
#  ['right', 'red', 'forward', 'left', 'right', '0'],
#  ['forward', 'green', 'right', 'right', 'right', '0'],
#  ['left', 'green', 'right', 'right', 'None', '0'],
#  ['left', 'green', 'left', 'right', 'forward', '0'],
#  ['right', 'red', 'right', 'right', 'None', '0'],
#  ['forward', 'green', 'right', 'left', 'forward', '0'],
#  ['forward', 'green', 'left', 'left', 'forward', '0'],
#  ['forward', 'red', 'None', 'None', 'right', '5.7702236128747195'],
#  ['forward', 'red', 'right', 'forward', 'right', '0'],
#  ['left', 'green', 'forward', 'right', 'None', '0'],
#  ['left', 'green', 'right', 'None', 'right', '1.3412629022444453'],
#  ['right', 'red', 'None', 'left', 'None', '0'],
#  ['right', 'green', 'left', 'right', 'right', '0'],
#  ['left', 'green', 'right', 'left', 'left', '0'],
#  ['right', 'red', 'None', 'None', 'right', '10.134647982231558'],
#  ['right', 'red', 'right', 'forward', 'right', '0'],
#  ['right', 'red', 'None', 'left', 'forward', '0'],
#  ['right', 'red', 'None', 'forward', 'left', '0'],
#  ['right', 'green', 'None', 'right', 'right', '0'],
#  ['forward', 'green', 'right', 'right', 'forward', '0'],
#  ['right', 'red', 'None', 'right', 'None', '0'],
#  ['right', 'green', 'None', 'left', 'right', '0'],
#  ['left', 'red', 'forward', 'None', 'forward', '0'],
#  ['left', 'green', 'None', 'forward', 'forward', '0.6754634696527833'],
#  ['right', 'red', 'None', 'left', 'right', '5.931169313862576'],
#  ['forward', 'green', 'left', 'forward', 'forward', '0.6771248602100167'],
#  ['left', 'red', 'right', 'right', 'right', '0'],
#  ['right', 'red', 'None', 'None', 'None', '7.766871467957359'],
#  ['forward', 'red', 'forward', 'left', 'left', '0'],
#  ['right', 'red', 'None', 'left', 'left', '-0.03709329858314941'],
#  ['right', 'red', 'forward', 'forward', 'None', '0'],
#  ['right', 'green', 'left', 'right', 'None', '0'],
#  ['forward', 'red', 'None', 'left', 'forward', '0.802641096857975'],
#  ['left', 'green', 'right', 'forward', 'left', '0'],
#  ['forward', 'red', 'None', 'None', 'forward', '4.834469470780058'],
#  ['right', 'green', 'None', 'forward', 'None', '1.1168740176355967'],
#  ['right', 'green', 'None', 'right', 'forward', '0'],
#  ['left', 'red', 'left', 'right', 'right', '0'],
#  ['left', 'red', 'forward', 'right', 'None', '0'],
#  ['right', 'red', 'left', 'forward', 'None', '0'],
#  ['left', 'green', 'left', 'forward', 'None', '0'],
#  ['left', 'red', 'left', 'right', 'None', '0'],
#  ['right', 'red', 'forward', 'right', 'right', '0'],
#  ['left', 'red', 'right', 'right', 'forward', '0'],
#  ['left', 'green', 'left', 'forward', 'left', '0'],
#  ['right', 'green', 'None', 'left', 'forward', '6.578357344828026'],
#  ['left', 'red', 'forward', 'None', 'None', '0'],
#  ['left', 'green', 'None', 'None', 'forward', '6.383561297372116'],
#  ['left', 'red', 'left', 'None', 'left', '0'],
#  ['left', 'green', 'right', 'right', 'left', '0'],
#  ['right', 'red', 'None', 'None', 'forward', '7.013104094431616'],
#  ['right', 'green', 'right', 'left', 'None', '0'],
#  ['left', 'red', 'forward', 'forward', 'None', '0'],
#  ['right', 'green', 'left', 'right', 'forward', '0'],
#  ['left', 'red', 'forward', 'forward', 'left', '0'],
#  ['left', 'red', 'right', 'left', 'left', '0'],
#  ['left', 'red', 'forward', 'forward', 'right', '0'],
#  ['forward', 'red', 'forward', 'forward', 'left', '0'],
#  ['right', 'red', 'None', 'forward', 'None', '0'],
#  ['right', 'red', 'left', 'right', 'None', '0'],
#  ['left', 'red', 'None', 'left', 'left', '0'],
#  ['left', 'red', 'right', 'right', 'left', '0'],
#  ['forward', 'green', 'forward', 'forward', 'forward', '0'],
#  ['forward', 'red', 'left', 'forward', 'left', '0'],
#  ['right', 'red', 'forward', 'right', 'None', '0'],
#  ['left', 'red', 'right', 'None', 'left', '0.4450148391870086'],
#  ['forward', 'red', 'None', 'None', 'left', '4.90063272817698'],
#  ['left', 'red', 'right', 'None', 'right', '0'],
#  ['right', 'red', 'left', 'forward', 'right', '0'],
#  ['forward', 'red', 'left', 'left', 'right', '0'],
#  ['forward', 'red', 'right', 'left', 'None', '0'],
#  ['left', 'green', 'right', 'None', 'None', '0'],
#  ['left', 'green', 'left', 'left', 'forward', '0'],
#  ['forward', 'green', 'forward', 'right', 'None', '0'],
#  ['forward', 'green', 'None', 'left', 'right', '6.387135761387643'],
#  ['left', 'green', 'None', 'None', 'left', '8.417527566768914'],
#  ['left', 'green', 'right', 'left', 'right', '0'],
#  ['forward', 'red', 'forward', 'forward', 'None', '0'],
#  ['left', 'red', 'None', 'forward', 'forward', '0'],
#  ['forward', 'green', 'None', 'left', 'None', '0.16693885471900183'],
#  ['left', 'red', 'None', 'left', 'forward', '0'],
#  ['left', 'green', 'left', 'left', 'left', '0'],
#  ['forward', 'green', 'left', 'right', 'right', '0'],
#  ['forward', 'red', 'None', 'left', 'None', '0'],
#  ['right', 'green', 'None', 'forward', 'right', '0.9676195344193573'],
#  ['left', 'green', 'right', 'right', 'forward', '0'],
#  ['forward', 'red', 'None', 'left', 'left', '-0.02334177885326795'],
#  ['left', 'red', 'right', 'None', 'None', '0'],
#  ['forward', 'red', 'right', 'forward', 'forward', '0'],
#  ['right', 'green', 'left', 'forward', 'forward', '0'],
#  ['forward', 'green', 'left', 'right', 'forward', '0'],
#  ['left', 'red', 'forward', 'None', 'left', '0'],
#  ['right', 'green', 'None', 'None', 'right', '9.590204241880524'],
#  ['forward', 'green', 'left', 'left', 'None', '0'],
#  ['left', 'red', 'forward', 'None', 'right', '5.759578489120832'],
#  ['left', 'red', 'right', 'forward', 'left', '0'],
#  ['left', 'green', 'right', 'None', 'left', '0'],
#  ['forward', 'green', 'forward', 'left', 'left', '0'],
#  ['left', 'red', 'forward', 'right', 'left', '0'],
#  ['left', 'green', 'forward', 'None', 'left', '0'],
#  ['right', 'green', 'None', 'forward', 'forward', '6.633684202915324'],
#  ['forward', 'green', 'None', 'None', 'forward', '10.745472756908264'],
#  ['forward', 'green', 'None', 'None', 'None', '7.645333791896753'],
#  ['forward', 'green', 'forward', 'forward', 'left', '0'],
#  ['left', 'red', 'None', 'None', 'None', '6.147418012168981'],
#  ['forward', 'green', 'None', 'forward', 'right', '0'],
#  ['left', 'green', 'forward', 'None', 'right', '0'],
#  ['forward', 'red', 'None', 'right', 'left', '1.9489890059393202'],
#  ['left', 'red', 'None', 'left', 'None', '1.3947231649927978'],
#  ['left', 'green', 'left', 'None', 'None', '0.6598061421974113'],
#  ['forward', 'green', 'left', 'left', 'left', '0'],
#  ['forward', 'green', 'right', 'right', 'None', '0.6597364557197207'],
#  ['right', 'green', 'right', 'forward', 'None', '0'],
#  ['left', 'red', 'None', 'forward', 'None', '0'],
#  ['forward', 'green', 'left', 'right', 'left', '0'],
#  ['left', 'red', 'forward', 'forward', 'forward', '0'],
#  ['forward', 'red', 'right', 'left', 'left', '0'],
#  ['left', 'red', 'left', 'left', 'None', '0'],
#  ['left', 'red', 'right', 'left', 'right', '0'],
#  ['left', 'red', 'left', 'forward', 'left', '0'],
#  ['forward', 'green', 'None', 'None', 'right', '6.887231354430366'],
#  ['left', 'red', 'left', 'forward', 'right', '0'],
#  ['forward', 'green', 'None', 'forward', 'None', '0'],
#  ['left', 'red', 'left', 'forward', 'forward', '0'],
#  ['left', 'green', 'right', 'right', 'right', '0'],
#  ['right', 'green', 'left', 'right', 'left', '0'],
#  ['forward', 'red', 'right', 'None', 'None', '0'],
#  ['forward', 'green', 'right', 'None', 'right', '0'],
#  ['left', 'red', 'forward', 'left', 'right', '0'],
#  ['forward', 'green', 'left', 'None', 'None', '0.4643694195297843'],
#  ['left', 'red', 'None', 'right', 'forward', '0'],
#  ['forward', 'green', 'None', 'forward', 'forward', '0'],
#  ['right', 'green', 'right', 'right', 'forward', '0'],
#  ['forward', 'red', 'left', 'right', 'None', '0'],
#  ['left', 'green', 'forward', 'forward', 'forward', '0'],
#  ['right', 'red', 'left', 'right', 'forward', '0'],
#  ['right', 'red', 'forward', 'None', 'None', '5.5314934462094705'],
#  ['right', 'green', 'forward', 'forward', 'left', '0'],
#  ['left', 'red', 'right', 'forward', 'right', '0'],
#  ['forward', 'green', 'forward', 'left', 'forward', '0'],
#  ['left', 'green', 'left', 'right', 'None', '0'],
#  ['left', 'red', 'forward', 'left', 'forward', '0'],
#  ['left', 'red', 'right', 'forward', 'forward', '0'],
#  ['left', 'green', 'forward', 'None', 'forward', '2.044044617601429'],
#  ['forward', 'red', 'None', 'forward', 'left', '0'],
#  ['left', 'red', 'left', 'left', 'left', '0'],
#  ['right', 'green', 'left', 'forward', 'None', '0'],
#  ['forward', 'green', 'forward', 'None', 'forward', '5.273755116996132'],
#  ['right', 'green', 'None', 'None', 'forward', '7.300528928133801'],
#  ['right', 'red', 'right', 'right', 'right', '0'],
#  ['forward', 'red', 'left', 'left', 'left', '0'],
#  ['forward', 'red', 'forward', 'right', 'None', '0'],
#  ['right', 'red', 'None', 'None', 'left', '6.923189222530351'],
#  ['left', 'green', 'left', 'right', 'left', '0'],
#  ['left', 'red', 'None', 'left', 'right', '0'],
#  ['forward', 'red', 'None', 'left', 'right', '4.281314735338079'],
#  ['right', 'green', 'forward', 'right', 'right', '0'],
#  ['right', 'green', 'left', 'left', 'None', '0'],
#  ['right', 'green', 'None', 'None', 'None', '7.73124430321338'],
#  ['right', 'red', 'right', 'right', 'left', '0'],
#  ['right', 'green', 'left', 'left', 'left', '0'],
#  ['forward', 'green', 'None', 'right', 'None', '1.521902784159229'],
#  ['left', 'red', 'left', 'right', 'forward', '0'],
#  ['forward', 'red', 'right', 'right', 'right', '0'],
#  ['right', 'red', 'left', 'forward', 'left', '0'],
#  ['left', 'red', 'None', 'right', 'right', '0'],
#  ['right', 'red', 'forward', 'left', 'forward', '0'],
#  ['right', 'red', 'right', 'None', 'forward', '0'],
#  ['right', 'green', 'forward', 'left', 'right', '0'],
#  ['right', 'green', 'forward', 'right', 'forward', '0'],
#  ['forward', 'red', 'left', 'forward', 'right', '0'],
#  ['left', 'green', 'right', 'left', 'None', '0'],
#  ['right', 'red', 'left', 'None', 'forward', '0.5763728686686628'],
#  ['left', 'red', 'None', 'None', 'left', '5.098326918191597'],
#  ['right', 'red', 'right', 'forward', 'None', '0'],
#  ['forward', 'red', 'forward', 'None', 'left', '0.7948395040385462'],
#  ['forward', 'red', 'None', 'right', 'forward', '0'],
#  ['left', 'green', 'left', 'forward', 'forward', '0'],
#  ['forward', 'red', 'forward', 'forward', 'right', '0'],
#  ['forward', 'red', 'forward', 'right', 'right', '0'],
#  ['forward', 'red', 'forward', 'left', 'None', '0'],
#  ['right', 'red', 'None', 'right', 'left', '0'],
#  ['right', 'green', 'right', 'None', 'left', '0'],
#  ['right', 'green', 'forward', 'right', 'left', '0'],
#  ['forward', 'green', 'None', 'right', 'right', '0'],
#  ['forward', 'red', 'left', 'None', 'forward', '0.5542734029616515'],
#  ['forward', 'green', 'forward', 'forward', 'None', '0'],
#  ['right', 'green', 'forward', 'None', 'None', '0'],
#  ['right', 'red', 'left', 'right', 'left', '0'],
#  ['forward', 'red', 'forward', 'right', 'left', '0'],
#  ['forward', 'red', 'right', 'left', 'forward', '0'],
#  ['left', 'green', 'forward', 'left', 'right', '0'],
#  ['forward', 'red', 'forward', 'right', 'forward', '0'],
#  ['forward', 'red', 'left', 'left', 'forward', '0'],
#  ['left', 'green', 'left', 'None', 'left', '0'],
#  ['left', 'green', 'None', 'None', 'right', '7.390205710943132'],
#  ['forward', 'green', 'right', 'left', 'right', '0'],
#  ['right', 'green', 'right', 'right', 'right', '0'],
#  ['left', 'green', 'forward', 'right', 'forward', '0'],
#  ['right', 'red', 'right', 'None', 'right', '0'],
#  ['forward', 'red', 'left', 'forward', 'forward', '0'],
#  ['right', 'red', 'right', 'None', 'None', '5.2023784646083335'],
#  ['right', 'green', 'left', 'forward', 'right', '0'],
#  ['right', 'green', 'left', 'left', 'forward', '0'],
#  ['right', 'green', 'forward', 'None', 'right', '0'],
#  ['left', 'green', 'None', 'right', 'forward', '2.078296997876489'],
#  ['right', 'green', 'None', 'None', 'left', '6.521686092508103'],
#  ['right', 'green', 'forward', 'left', 'None', '0'],
#  ['right', 'red', 'left', 'None', 'left', '0.7555759043677379'],
#  ['left', 'green', 'forward', 'right', 'left', '0'],
#  ['right', 'red', 'None', 'forward', 'right', '0'],
#  ['right', 'red', 'right', 'None', 'left', '0'],
#  ['forward', 'green', 'forward', 'forward', 'right', '0.7308462471237112'],
#  ['forward', 'green', 'None', 'forward', 'left', '6.709776570945703'],
#  ['right', 'green', 'forward', 'None', 'left', '0'],
#  ['forward', 'green', 'right', 'forward', 'left', '0'],
#  ['left', 'red', 'None', 'None', 'right', '7.298131651700424'],
#  ['forward', 'red', 'right', 'right', 'forward', '0'],
#  ['right', 'red', 'right', 'right', 'forward', '0'],
#  ['left', 'green', 'None', 'forward', 'left', '8.436708475152413'],
#  ['right', 'green', 'left', 'forward', 'left', '0'],
#  ['right', 'red', 'forward', 'right', 'forward', '0'],
#  ['right', 'green', 'right', 'left', 'left', '0.6843203010361223'],
#  ['right', 'red', 'forward', 'right', 'left', '0'],
#  ['forward', 'green', 'left', 'left', 'right', '0'],
#  ['forward', 'red', 'None', 'forward', 'forward', '0'],
#  ['forward', 'green', 'forward', 'None', 'left', '0'],
#  ['left', 'green', 'right', 'left', 'forward', '0'],
#  ['forward', 'green', 'forward', 'None', 'None', '0'],
#  ['left', 'red', 'None', 'right', 'None', '0'],
#  ['left', 'red', 'left', 'right', 'left', '0'],
#  ['right', 'green', 'left', 'None', 'forward', '6.173140362935509'],
#  ['forward', 'green', 'left', 'forward', 'left', '0'],
#  ['forward', 'green', 'right', 'forward', 'forward', '0'],
#  ['left', 'red', 'None', 'right', 'left', '1.0627382241705847'],
#  ['right', 'red', 'left', 'right', 'right', '0'],
#  ['right', 'green', 'forward', 'left', 'left', '0'],
#  ['left', 'red', 'None', 'forward', 'left', '2.767380540796929'],
#  ['left', 'red', 'forward', 'left', 'left', '0'],
#  ['right', 'red', 'left', 'left', 'left', '0'],
#  ['forward', 'red', 'None', 'right', 'right', '0'],
#  ['right', 'green', 'right', 'left', 'right', '0'],
#  ['forward', 'red', 'right', 'right', 'None', '0'],
#  ['left', 'green', 'left', 'None', 'right', '4.9382313412809555'],
#  ['forward', 'red', 'None', 'right', 'None', '0'],
#  ['forward', 'red', 'left', 'right', 'left', '0'],
#  ['left', 'green', 'forward', 'left', 'forward', '0'],
#  ['forward', 'red', 'forward', 'None', 'forward', '0.6205485141583856'],
#  ['forward', 'green', 'None', 'left', 'left', '0'],
#  ['right', 'green', 'right', 'right', 'None', '0'],
#  ['right', 'green', 'right', 'forward', 'forward', '0'],
#  ['right', 'red', 'left', 'forward', 'forward', '0'],
#  ['right', 'green', 'right', 'None', 'None', '4.27054641290417'],
#  ['right', 'red', 'right', 'left', 'left', '0'],
#  ['forward', 'red', 'left', 'None', 'None', '0.505760984719854'],
#  ['left', 'red', 'forward', 'right', 'forward', '0'],
#  ['right', 'red', 'None', 'forward', 'forward', '3.523502334785644'],
#  ['right', 'red', 'left', 'None', 'right', '9.001299444429602'],
#  ['left', 'red', 'right', 'left', 'forward', '0'],
#  ['forward', 'red', 'right', 'forward', 'None', '0']]

# %%
map(to_str, a.qt)

# %%
pd.DataFrame(arr)
# Out:
#            0      1        2        3        4                    5
# 0    forward    red     None  forward     None    3.678748210927025
# 1       left    red     left     None  forward                    0
# 2       left    red     left     None     None    4.025578411370011
# 3    forward  green     left    right     None                    0
# 4    forward    red  forward     left    right                    0
# 5       left  green     None     left     None  0.49005492241889165
# 6       left  green    right  forward  forward                    0
# 7    forward    red    right  forward     left                    0
# 8    forward  green  forward    right     left                    0
# 9      right  green     None  forward     left   1.0355756747201827
# 10      left    red     left     None    right                    0
# 11      left    red  forward     left     None                    0
# 12   forward    red  forward     None     None    7.037651954668828
# 13     right    red     left     left  forward                    0
# 14   forward    red    right     None  forward                    0
# 15   forward  green     None     left  forward                    0
# 16     right  green  forward    right     None                    0
# 17      left  green    right  forward    right                    0
# 18   forward  green    right     left     None                    0
# 19      left  green     None     left  forward                    0
# 20      left  green  forward     None     None                    0
# 21      left  green     None     left     left                    0
# 22      left    red    right     left     None                    0
# 23     right    red     left     left    right                    0
# 24   forward  green    right  forward    right                    0
# 25     right    red    right     left  forward                    0
# 26   forward    red     left     None    right    6.229636886231188
# 27     right    red  forward     left     None                    0
# 28      left  green     left     left    right                    0
# 29      left    red     left     left  forward                    0
# ..       ...    ...      ...      ...      ...                  ...
# 354     left    red     left    right     left                    0
# 355    right  green     left     None  forward    6.173140362935509
# 356  forward  green     left  forward     left                    0
# 357  forward  green    right  forward  forward                    0
# 358     left    red     None    right     left   1.0627382241705847
# 359    right    red     left    right    right                    0
# 360    right  green  forward     left     left                    0
# 361     left    red     None  forward     left    2.767380540796929
# 362     left    red  forward     left     left                    0
# 363    right    red     left     left     left                    0
# 364  forward    red     None    right    right                    0
# 365    right  green    right     left    right                    0
# 366  forward    red    right    right     None                    0
# 367     left  green     left     None    right   4.9382313412809555
# 368  forward    red     None    right     None                    0
# 369  forward    red     left    right     left                    0
# 370     left  green  forward     left  forward                    0
# 371  forward    red  forward     None  forward   0.6205485141583856
# 372  forward  green     None     left     left                    0
# 373    right  green    right    right     None                    0
# 374    right  green    right  forward  forward                    0
# 375    right    red     left  forward  forward                    0
# 376    right  green    right     None     None     4.27054641290417
# 377    right    red    right     left     left                    0
# 378  forward    red     left     None     None    0.505760984719854
# 379     left    red  forward    right  forward                    0
# 380    right    red     None  forward  forward    3.523502334785644
# 381    right    red     left     None    right    9.001299444429602
# 382     left    red    right     left  forward                    0
# 383  forward    red    right  forward     None                    0
#
# [384 rows x 6 columns]
